# %%
import sqlite3
import pandas as py
import numpy as np

# %%
def create_table():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS employees (
            id INTEGER PRIMARY KEY,
            name TEXT NOT NULL,
            age INTEGER,
            department TEXT
        )
    ''')
    conn.commit()
    conn.close()
    print("Table 'employees' created successfully.")

create_table()
# Out:
# Table 'employees' created successfully.

# %%
def add_emp(id, name, age, dept):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()

    cursor.execute('''
       Insert into employees(id, name, age, department)
       Values(?, ?, ?, ?)''',(id, name, age, dept))

    conn.commit()
    print("Values Inserted")

def show():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()

    cursor.execute('Select * From employees')
    rows = cursor.fetchall()

    for row in rows:
        print(row)

    conn.commit
    
    

while True:
    # id = int(input("Enter employee ID: "))
    # name = input("Enter employee name: ")
    # age = int(input("Enter employee age: "))
    # department = input("Enter employee department: ")

    add_emp(8291, 'Race', 32, 'car')

    choice = input("Do you want to add another employee? (yes/no): ")

    if choice.lower() == "no":
        break

print("Program stopped.")
show()
# Out:
# Values Inserted
# Program stopped.
# (2004, 'Tushar', 21, 'Data science')
# (3212, 'fuah', 810, 'idk')
# (3454, 'baam', 28, 'SDE')
# (4532, 'yeti', 89909, 'mon')
# (8272, 'Prasu', 34, 'cute')
# (8291, 'Race', 32, 'car')

# %%
def update():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()

    cursor.execute('Update employees set department = "magic" where id = 3212')

    conn.commit()

update()

# %%
def delet():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()

    cursor.execute('Delete from employees where id = 3212')

    conn.commit()

delet()

# %%
def age():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()

    cursor.execute('Select * from employees where age > 100')
    rows = cursor.fetchall()
    conn.close()
    for row in rows:
        print(row)

age()
# Out:
# (4532, 'yeti', 89909, 'mon')

# %%
def update_age(age):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    try:
        cursor.execute('Update employees age = ?'(age))
        conn.commit()
    except Exception as e:
        conn.rollback()
        print("transaction failed")
    finally:
        conn.close()
# Out:
#   Cell In[30], line 1
#     def update_age():
#                      ^
# _IncompleteInputError: incomplete input
